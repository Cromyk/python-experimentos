# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/leonhgomes/Pandas/main/pokemon_data.csv')
# Acessando o nome das colunas e  o inicio e fim da tabela
df

#print (df.columns )
#print(df.head(3))
#print(df.tail(2))
# Out:
#        #                   Nome    Tipo 1    Tipo 2  Vida  Ataque  Defensa  \
# 0      1              Bulbasaur    Planta  Venenoso    45      49       49
# 1      2                Ivysaur    Planta  Venenoso    60      62       63
# 2      3               Venusaur    Planta  Venenoso    80      82       83
# 3      3  VenusaurMega Venusaur    Planta  Venenoso    80     100      123
# 4      4             Charmander      Fogo       NaN    39      52       43
# ..   ...                    ...       ...       ...   ...     ...      ...
# 795  719                Diancie     Pedra      Fada    50     100      150
# 796  719    DiancieMega Diancie     Pedra      Fada    50     160      110
# 797  720    HoopaHoopa Confined  Psiquico  Fantasma    80     110       60
# 798  720     HoopaHoopa Unbound  Psiquico   Noturno    80     160       60
# 799  721              Volcanion      Fogo      Agua    80     110      120
#
#      Atq Esp  Def Esp  Velocidade  Geracao  Lendario
# ...

# %%
#Acessar colunas individuais

df['Nome']
df[['Nome','Tipo 1']][0:150:2]

# %%
# Acessando linhas individuais
df.iloc[:4]
# Out:
#    #                   Nome  Tipo 1    Tipo 2  Vida  Ataque  Defensa  Atq Esp  \
# 0  1              Bulbasaur  Planta  Venenoso    45      49       49       65
# 1  2                Ivysaur  Planta  Venenoso    60      62       63       80
# 2  3               Venusaur  Planta  Venenoso    80      82       83      100
# 3  3  VenusaurMega Venusaur  Planta  Venenoso    80     100      123      122
#
#    Def Esp  Velocidade  Geracao  Lendario
# 0       65          45        1     False
# 1       80          60        1     False
# 2      100          80        1     False
# 3      120          80        1     False

# %%
df.iloc[2,1]
# Out:
# 'Venusaur'

# %%
#df.iloc para localizar indice (linha)
df.iloc[44]
# Out:
# #                     39
# Nome          Jigglypuff
# Tipo 1            Normal
# Tipo 2              Fada
# Vida                 115
# Ataque                45
# Defensa               20
# Atq Esp               45
# Def Esp               25
# Velocidade            20
# Geracao                1
# Lendario           False
# Name: 44, dtype: object

# %%
# df.loc para localizar
df.loc[df['Tipo 1'] == 'Fogo']
# Out:
#        #                       Nome Tipo 1    Tipo 2  Vida  Ataque  Defensa  \
# 4      4                 Charmander   Fogo       NaN    39      52       43
# 5      5                 Charmeleon   Fogo       NaN    58      64       58
# 6      6                  Charizard   Fogo    Voador    78      84       78
# 7      6  CharizardMega Charizard X   Fogo    Dragao    78     130      111
# 8      6  CharizardMega Charizard Y   Fogo    Voador    78     104       78
# 42    37                     Vulpix   Fogo       NaN    38      41       40
# 43    38                  Ninetales   Fogo       NaN    73      76       75
# 63    58                  Growlithe   Fogo       NaN    55      70       45
# 64    59                   Arcanine   Fogo       NaN    90     110       80
# 83    77                     Ponyta   Fogo       NaN    50      85       55
# 84    78                   Rapidash   Fogo       NaN    65     100       70
# ...

# %%
#acessar linhas por nome
#iterriws gera uma lista de linhas
# indice recebe o indice e a linha recebe o conteudo da linha
for indice,linha in df.iterrows():
  print(indice,linha['Nome'])
  if linha['#'] == 150:
    break
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 CleFada
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
#valores estatísticos básicos
df.describe()
# count = contagem das linhas
# mean  = média
#std = range da distancia da média
# Out:
#                 #        Vida      Ataque     Defensa     Atq Esp     Def Esp  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#        Velocidade    Geracao
# count  800.000000  800.00000
# mean    68.277500    3.32375
# std     29.060474    1.66129
# min      5.000000    1.00000
# 25%     45.000000    2.00000
# 50%     65.000000    3.00000
# 75%     90.000000    5.00000
# ...

# %% [markdown]
# #Ordenação

# %%
#ordenar por ordem alfabetica
df.sort_values('Nome')
# Out:
#        #                     Nome    Tipo 1  Tipo 2  Vida  Ataque  Defensa  \
# 510  460                Abomasnow    Planta    Gelo    90      92       75
# 511  460  AbomasnowMega Abomasnow    Planta    Gelo    90     132      105
# 68    63                     Abra  Psiquico     NaN    25      20       15
# 392  359                    Absol   Noturno     NaN    65     130       60
# 393  359          AbsolMega Absol   Noturno     NaN    65     150       60
# ..   ...                      ...       ...     ...   ...     ...      ...
# 632  571                  Zoroark   Noturno     NaN    60     105       60
# 631  570                    Zorua   Noturno     NaN    40      65       40
# 46    41                    Zubat  Venenoso  Voador    40      45       35
# 695  634                 Zweilous   Noturno  Dragao    72      85       70
# 794  718         Zygarde50% Forme    Dragao   Terra   108     100      121
#
#      Atq Esp  Def Esp  Velocidade  Geracao  Lendario
# ...

# %%
#ordenar por ordem alfabetica inversa
#inplace=True aplica o sort dentro do proprio df  (Data Frame)
df.sort_values('Nome', ascending = False, inplace=True)

# %%
print(df)
# Out:
#        #                     Nome    Tipo 1  Tipo 2  Vida  Ataque  Defensa  \
# 794  718         Zygarde50% Forme    Dragao   Terra   108     100      121
# 695  634                 Zweilous   Noturno  Dragao    72      85       70
# 46    41                    Zubat  Venenoso  Voador    40      45       35
# 631  570                    Zorua   Noturno     NaN    40      65       40
# 632  571                  Zoroark   Noturno     NaN    60     105       60
# ..   ...                      ...       ...     ...   ...     ...      ...
# 393  359          AbsolMega Absol   Noturno     NaN    65     150       60
# 392  359                    Absol   Noturno     NaN    65     130       60
# 68    63                     Abra  Psiquico     NaN    25      20       15
# 511  460  AbomasnowMega Abomasnow    Planta    Gelo    90     132      105
# 510  460                Abomasnow    Planta    Gelo    90      92       75
#
#      Atq Esp  Def Esp  Velocidade  Geracao  Lendario
# ...

# %% [markdown]
# # Realizando mudanças nos dados

# %%
df['Total'] = df['Ataque']+df['Atq Esp']+df['Def Esp'] + df['Defesa'] + df['Velocidade'] + df['Vida']
df
# Out:
# <ipython-input-54-e486811feda6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total'] = df['Ataque']+df['Atq Esp']+df['Def Esp'] + df['Defesa'] + df['Velocidade'] + df['Vida']
#        #                   Nome    Tipo 1    Tipo 2  Lendario  Vida  Ataque  \
# 0      1              Bulbasaur    Planta  Venenoso     False    45      49
# 1      2                Ivysaur    Planta  Venenoso     False    60      62
# 2      3               Venusaur    Planta  Venenoso     False    80      82
# 3      3  VenusaurMega Venusaur    Planta  Venenoso     False    80     100
# 4      4             Charmander      Fogo       NaN     False    39      52
# ..   ...                    ...       ...       ...       ...   ...     ...
# ...

# %%
#remover coluna Total
df = df.drop(columns=['Total'])
df
# Out:
#        #                   Nome    Tipo 1    Tipo 2  Lendario  Lendario  Vida  \
# 0      1              Bulbasaur    Planta  Venenoso     False     False    45
# 1      2                Ivysaur    Planta  Venenoso     False     False    60
# 2      3               Venusaur    Planta  Venenoso     False     False    80
# 3      3  VenusaurMega Venusaur    Planta  Venenoso     False     False    80
# 4      4             Charmander      Fogo       NaN     False     False    39
# ..   ...                    ...       ...       ...       ...       ...   ...
# 795  719                Diancie     Pedra      Fada      True      True    50
# 796  719    DiancieMega Diancie     Pedra      Fada      True      True    50
# 797  720    HoopaHoopa Confined  Psiquico  Fantasma      True      True    80
# 798  720     HoopaHoopa Unbound  Psiquico   Noturno      True      True    80
# 799  721              Volcanion      Fogo      Agua      True      True    80
#
# ...

# %%
#forma alternatica de cirar coluna Total
df['Total'] = df.iloc[:,4:10].sum(axis=1)
df
# Out:
#        #                     Nome    Tipo 1  Tipo 2  Vida  Ataque  Defensa  \
# 794  718         Zygarde50% Forme    Dragao   Terra   108     100      121
# 695  634                 Zweilous   Noturno  Dragao    72      85       70
# 46    41                    Zubat  Venenoso  Voador    40      45       35
# 631  570                    Zorua   Noturno     NaN    40      65       40
# 632  571                  Zoroark   Noturno     NaN    60     105       60
# ..   ...                      ...       ...     ...   ...     ...      ...
# 393  359          AbsolMega Absol   Noturno     NaN    65     150       60
# 392  359                    Absol   Noturno     NaN    65     130       60
# 68    63                     Abra  Psiquico     NaN    25      20       15
# 511  460  AbomasnowMega Abomasnow    Planta    Gelo    90     132      105
# 510  460                Abomasnow    Planta    Gelo    90      92       75
#
#      Atq Esp  Def Esp  Velocidade  Geracao  Lendario  Total
# ...

# %%
df.rename({'Defensa':'Defesa'},axis=1,inplace=True)
df
# Out:
#        #                   Nome    Tipo 1    Tipo 2  Vida  Ataque  Defesa  \
# 0      1              Bulbasaur    Planta  Venenoso    45      49      49
# 1      2                Ivysaur    Planta  Venenoso    60      62      63
# 2      3               Venusaur    Planta  Venenoso    80      82      83
# 3      3  VenusaurMega Venusaur    Planta  Venenoso    80     100     123
# 4      4             Charmander      Fogo       NaN    39      52      43
# ..   ...                    ...       ...       ...   ...     ...     ...
# 795  719                Diancie     Pedra      Fada    50     100     150
# 796  719    DiancieMega Diancie     Pedra      Fada    50     160     110
# 797  720    HoopaHoopa Confined  Psiquico  Fantasma    80     110      60
# 798  720     HoopaHoopa Unbound  Psiquico   Noturno    80     160      60
# 799  721              Volcanion      Fogo      Agua    80     110     120
#
#      Atq Esp  Def Esp  Velocidade  Geracao  Lendario
# ...

# %%
df['Total'] = df['Ataque'] + df['Atq Esp'] + df['Def Esp'] + df['Defesa'] + df['Velocidade'] + df['Vida']
df
# Out:
#        #                   Nome    Tipo 1    Tipo 2  Vida  Ataque  Defesa  \
# 0      1              Bulbasaur    Planta  Venenoso    45      49      49
# 1      2                Ivysaur    Planta  Venenoso    60      62      63
# 2      3               Venusaur    Planta  Venenoso    80      82      83
# 3      3  VenusaurMega Venusaur    Planta  Venenoso    80     100     123
# 4      4             Charmander      Fogo       NaN    39      52      43
# ..   ...                    ...       ...       ...   ...     ...     ...
# 795  719                Diancie     Pedra      Fada    50     100     150
# 796  719    DiancieMega Diancie     Pedra      Fada    50     160     110
# 797  720    HoopaHoopa Confined  Psiquico  Fantasma    80     110      60
# 798  720     HoopaHoopa Unbound  Psiquico   Noturno    80     160      60
# 799  721              Volcanion      Fogo      Agua    80     110     120
#
#      Atq Esp  Def Esp  Velocidade  Geracao  Lendario  Total
# ...

# %%
#reordenar colunas

#df = df[['Total','Vida']]

cols = list(df.columns. values)
df = df [cols[0:4] + [cols[-1]]  + cols[4:12] ]
df
# Out:
#        #                   Nome    Tipo 1    Tipo 2  Total  Vida  Ataque  \
# 0      1              Bulbasaur    Planta  Venenoso    318    45      49
# 1      2                Ivysaur    Planta  Venenoso    405    60      62
# 2      3               Venusaur    Planta  Venenoso    525    80      82
# 3      3  VenusaurMega Venusaur    Planta  Venenoso    625    80     100
# 4      4             Charmander      Fogo       NaN    309    39      52
# ..   ...                    ...       ...       ...    ...   ...     ...
# 795  719                Diancie     Pedra      Fada    600    50     100
# 796  719    DiancieMega Diancie     Pedra      Fada    700    50     160
# 797  720    HoopaHoopa Confined  Psiquico  Fantasma    600    80     110
# 798  720     HoopaHoopa Unbound  Psiquico   Noturno    680    80     160
# 799  721              Volcanion      Fogo      Agua    600    80     110
#
#      Defesa  Atq Esp  Def Esp  Velocidade  Geracao  Lendario
# ...

# %% [markdown]
# #Salvar arquivos

# %%
#df.to_csv('modificado.csv')
df.to_csv('modificado.csv', index=False)
#separador diferente..  Tab   = '\t'
#df.to_csv('modificado.txt',index = False. sep='\t'),
#df.to_excel('modificado.xlsx',index = False)

# %%
[1,2,3]*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
